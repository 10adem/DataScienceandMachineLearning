# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data1 = np.linspace(0,10,20)

# %%
data1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
data2 = data1 ** 2

# %%
plt.subplots()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
my_fig, my_axes = plt.subplots()

# %%
type(my_fig)
# Out:
# matplotlib.figure.Figure

# %%
type(my_axes)
# Out:
# matplotlib.axes._axes.Axes

# %%
my_fig, my_axes = plt.subplots()
my_axes.plot(data1, data2, color="#1E0703", alpha=0.5)
my_axes.plot(data2, data1, color="#53CA0A")
plt.show()

# %%
(new_fig, new_axes) = plt.subplots()

new_axes.plot(data1, data1 + 2, color="blue", linewidth=1.0)
new_axes.plot(data1, data1 + 3, color="yellow", linewidth=4.0)

new_axes.plot(data1, data1 + 4, color="#C85D09", linestyle="dashed")
new_axes.plot(data1, data1 + 5, color="#C85D09", linestyle="-.")
new_axes.plot(data1, data1 + 6, color="#C85D09", linestyle=":")
new_axes.plot(data1, data1 + 7, color="#C85D09", linestyle="--")

new_axes.plot(data1, data1 + 8, color="#000000", linestyle="--", marker="o", markersize=8, markerfacecolor="red")
new_axes.plot(data1, data1 + 9, color="#000000", linestyle="--", marker="+", markersize=4)


plt.show()

# %% [markdown]
# # scatter

# %%
plt.scatter(data1, data2)

# %%
plt.scatter(data1, data2, color="black")
plt.show()

# %% [markdown]
# # histogram

# %%
new_arr = np.random.randint(0,100,50)

# %%
new_arr
# Out:
# array([ 5, 71, 44,  0, 19, 99, 45, 24, 27, 52, 97, 63, 88, 50, 45, 38, 87,
#        78, 86, 40, 37,  2, 61, 38, 55, 44, 70,  6, 77, 92, 94, 20, 52, 45,
#         5, 80, 17, 29, 87, 62, 38, 56, 57, 21, 47, 35, 16, 23, 21, 62],
#       dtype=int32)

# %%
plt.hist(new_arr)
plt.show()

# %% [markdown]
# # box plot

# %%
plt.boxplot(new_arr)
plt.show()
