# %%
import numpy as np
import pandas as pd

# %%
weather_df = pd.read_excel('6-weather.xlsx')

# %%
weather_df
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 0        20        10         15     12
# 1        21        10         17     14
# 2        20        13         18     15
# 3        22        14         19     18
# 4        25        15         15     20
# 5        28        13         22     16
# 6        15        12         15     15
# 7        20        15         14     14
# 8        22        16         16     16

# %%
weather_df.head()
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 0        20        10         15     12
# 1        21        10         17     14
# 2        20        13         18     15
# 3        22        14         19     18
# 4        25        15         15     20

# %%
weather_df.tail()
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 4        25        15         15     20
# 5        28        13         22     16
# 6        15        12         15     15
# 7        20        15         14     14
# 8        22        16         16     16

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Istanbul   9 non-null      int64
#  1   New York   9 non-null      int64
#  2   Amsterdam  9 non-null      int64
#  3   Paris      9 non-null      int64
# dtypes: int64(4)
# memory usage: 420.0 bytes

# %%
weather_df.describe() # datayı bize betimle ne anlatıyor
# Out:
#         Istanbul   New York  Amsterdam      Paris
# count   9.000000   9.000000   9.000000   9.000000
# mean   21.444444  13.111111  16.777778  15.555556
# std     3.609401   2.147350   2.538591   2.351123
# min    15.000000  10.000000  14.000000  12.000000
# 25%    20.000000  12.000000  15.000000  14.000000
# 50%    21.000000  13.000000  16.000000  15.000000
# 75%    22.000000  15.000000  18.000000  16.000000
# max    28.000000  16.000000  22.000000  20.000000

# %%
weather_df.count()
# Out:
# Istanbul     9
# New York     9
# Amsterdam    9
# Paris        9
# dtype: int64

# %%
weather_df.isna() # boş bir data var mı? (missing data)
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 0     False     False      False  False
# 1     False     False      False  False
# 2     False     False      False  False
# 3     False     False      False  False
# 4     False     False      False  False
# 5     False     False      False  False
# 6     False     False      False  False
# 7     False     False      False  False
# 8     False     False      False  False

# %% [markdown]
# # working with missing data

# %%
weather_na_df = pd.read_excel('6-weatherna.xlsx')

# %%
weather_na_df
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 0      20.0      10.0       15.0   12.0
# 1      21.0      10.0        NaN   14.0
# 2       NaN      13.0       18.0   15.0
# 3      22.0      14.0       19.0   18.0
# 4      25.0      15.0       15.0   20.0
# 5      28.0       NaN       22.0    NaN
# 6      15.0      12.0       15.0   15.0
# 7      20.0      15.0       14.0    NaN
# 8      22.0      16.0       16.0    NaN

# %%
weather_na_df.isna()
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 0     False     False      False  False
# 1     False     False       True  False
# 2      True     False      False  False
# 3     False     False      False  False
# 4     False     False      False  False
# 5     False      True      False   True
# 6     False     False      False  False
# 7     False     False      False   True
# 8     False     False      False   True

# %%
weather_na_df.describe()
# Out:
#         Istanbul   New York  Amsterdam      Paris
# count   8.000000   8.000000   8.000000   6.000000
# mean   21.625000  13.125000  16.750000  15.666667
# std     3.814914   2.295181   2.712405   2.875181
# min    15.000000  10.000000  14.000000  12.000000
# 25%    20.000000  11.500000  15.000000  14.250000
# 50%    21.500000  13.500000  15.500000  15.000000
# 75%    22.750000  15.000000  18.250000  17.250000
# max    28.000000  16.000000  22.000000  20.000000

# %%
weather_na_df['Paris']
# Out:
# 0    12.0
# 1    14.0
# 2    15.0
# 3    18.0
# 4    20.0
# 5     NaN
# 6    15.0
# 7     NaN
# 8     NaN
# Name: Paris, dtype: float64

# %%
weather_na_df['Paris'].count()
# Out:
# np.int64(6)

# %%
weather_na_df['Amsterdam'].count()
# Out:
# np.int64(8)

# %%
weather_na_df['Paris'].isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7     True
# 8     True
# Name: Paris, dtype: bool

# %%
weather_na_df
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 0      20.0      10.0       15.0   12.0
# 1      21.0      10.0        NaN   14.0
# 2       NaN      13.0       18.0   15.0
# 3      22.0      14.0       19.0   18.0
# 4      25.0      15.0       15.0   20.0
# 5      28.0       NaN       22.0    NaN
# 6      15.0      12.0       15.0   15.0
# 7      20.0      15.0       14.0    NaN
# 8      22.0      16.0       16.0    NaN

# %%
weather_na_df.dropna() # satırların en az birinde na varsa tüm satırı siliyor.
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 0      20.0      10.0       15.0   12.0
# 3      22.0      14.0       19.0   18.0
# 4      25.0      15.0       15.0   20.0
# 6      15.0      12.0       15.0   15.0

# %%
weather_na_df.dropna(axis=1) # kolonda na varsa siler çok mantıklı değil
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
weather_na_df.dropna(axis=0)
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 0      20.0      10.0       15.0   12.0
# 3      22.0      14.0       19.0   18.0
# 4      25.0      15.0       15.0   20.0
# 6      15.0      12.0       15.0   15.0

# %%
weather_na_df
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 0      20.0      10.0       15.0   12.0
# 1      21.0      10.0        NaN   14.0
# 2       NaN      13.0       18.0   15.0
# 3      22.0      14.0       19.0   18.0
# 4      25.0      15.0       15.0   20.0
# 5      28.0       NaN       22.0    NaN
# 6      15.0      12.0       15.0   15.0
# 7      20.0      15.0       14.0    NaN
# 8      22.0      16.0       16.0    NaN

# %%
weather_na_df.drop('Paris', axis=1)
# Out:
#    Istanbul  New York  Amsterdam
# 0      20.0      10.0       15.0
# 1      21.0      10.0        NaN
# 2       NaN      13.0       18.0
# 3      22.0      14.0       19.0
# 4      25.0      15.0       15.0
# 5      28.0       NaN       22.0
# 6      15.0      12.0       15.0
# 7      20.0      15.0       14.0
# 8      22.0      16.0       16.0

# %%
weather_na_df
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 0      20.0      10.0       15.0   12.0
# 1      21.0      10.0        NaN   14.0
# 2       NaN      13.0       18.0   15.0
# 3      22.0      14.0       19.0   18.0
# 4      25.0      15.0       15.0   20.0
# 5      28.0       NaN       22.0    NaN
# 6      15.0      12.0       15.0   15.0
# 7      20.0      15.0       14.0    NaN
# 8      22.0      16.0       16.0    NaN

# %%
weather_na_df.fillna(20) # boş olanları doldur.
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 0      20.0      10.0       15.0   12.0
# 1      21.0      10.0       20.0   14.0
# 2      20.0      13.0       18.0   15.0
# 3      22.0      14.0       19.0   18.0
# 4      25.0      15.0       15.0   20.0
# 5      28.0      20.0       22.0   20.0
# 6      15.0      12.0       15.0   15.0
# 7      20.0      15.0       14.0   20.0
# 8      22.0      16.0       16.0   20.0

# %%
weather_na_df
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 0      20.0      10.0       15.0   12.0
# 1      21.0      10.0        NaN   14.0
# 2       NaN      13.0       18.0   15.0
# 3      22.0      14.0       19.0   18.0
# 4      25.0      15.0       15.0   20.0
# 5      28.0       NaN       22.0    NaN
# 6      15.0      12.0       15.0   15.0
# 7      20.0      15.0       14.0    NaN
# 8      22.0      16.0       16.0    NaN

# %%
weather_na_df.mean()
# Out:
# Istanbul     21.625000
# New York     13.125000
# Amsterdam    16.750000
# Paris        15.666667
# dtype: float64

# %%
weather_na_df.median()
# Out:
# Istanbul     21.5
# New York     13.5
# Amsterdam    15.5
# Paris        15.0
# dtype: float64

# %%
weather_na_df.fillna(weather_na_df.mean()) # boşlukları her kolonun kendi ortalamaları ile doldur.
# Out:
#    Istanbul  New York  Amsterdam      Paris
# 0    20.000    10.000      15.00  12.000000
# 1    21.000    10.000      16.75  14.000000
# 2    21.625    13.000      18.00  15.000000
# 3    22.000    14.000      19.00  18.000000
# 4    25.000    15.000      15.00  20.000000
# 5    28.000    13.125      22.00  15.666667
# 6    15.000    12.000      15.00  15.000000
# 7    20.000    15.000      14.00  15.666667
# 8    22.000    16.000      16.00  15.666667

# %%
weather_na_df.max()
# Out:
# Istanbul     28.0
# New York     16.0
# Amsterdam    22.0
# Paris        20.0
# dtype: float64

# %%
weather_na_df.min()
# Out:
# Istanbul     15.0
# New York     10.0
# Amsterdam    14.0
# Paris        12.0
# dtype: float64

# %% [markdown]
# # group by

# %%
df = pd.read_csv('6-employee.csv')

# %%
df
# Out:
#    Department Employee  Salary  Experience           City
# 0   Marketing    Emp_1   53483           1       New York
# 1       Sales    Emp_2   78555           8         Austin
# 2     Finance    Emp_3   47159           3         Austin
# 3       Sales    Emp_4  110077           3  San Francisco
# 4       Sales    Emp_5   65920           1       New York
# 5          IT    Emp_6   97121          11        Chicago
# 6     Finance    Emp_7   99479           5        Chicago
# 7     Finance    Emp_8  119475          10       New York
# 8     Finance    Emp_9   49457           7        Chicago
# 9       Sales   Emp_10   96557          10        Chicago
# 10  Marketing   Emp_11  107189           9       New York
# 11    Finance   Emp_12  108953          12         Austin
# 12      Sales   Emp_13   82995           7       New York
# 13         IT   Emp_14   70757           9         Austin
# 14  Marketing   Emp_15   39692           8        Chicago
# ...

# %%
df.head()
# Out:
#   Department Employee  Salary  Experience           City
# 0  Marketing    Emp_1   53483           1       New York
# 1      Sales    Emp_2   78555           8         Austin
# 2    Finance    Emp_3   47159           3         Austin
# 3      Sales    Emp_4  110077           3  San Francisco
# 4      Sales    Emp_5   65920           1       New York

# %%
df.describe()
# Out:
#               Salary  Experience
# count      50.000000   50.000000
# mean    78344.500000    7.060000
# std     27817.603904    3.966235
# min     31016.000000    1.000000
# 25%     53687.250000    3.000000
# 50%     78769.500000    7.000000
# 75%    100778.000000   10.000000
# max    119812.000000   14.000000

# %%
# df.mean() alamaz

# %%
df['Salary'].mean()
# Out:
# np.float64(78344.5)

# %%
df[['Salary', 'Experience']].mean()
# Out:
# Salary        78344.50
# Experience        7.06
# dtype: float64

# %%
df.count()
# Out:
# Department    50
# Employee      50
# Salary        50
# Experience    50
# City          50
# dtype: int64

# %%
df['Experience'] > 6
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16    False
# 17    False
# 18     True
# 19     True
# 20     True
# 21     True
# 22    False
# 23    False
# 24     True
# 25     True
# 26    False
# 27     True
# 28    False
# 29    False
# 30    False
# 31    False
# 32     True
# 33    False
# 34    False
# 35    False
# 36     True
# 37     True
# 38     True
# 39     True
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46    False
# 47     True
# 48    False
# 49    False
# Name: Experience, dtype: bool

# %%
df[df['Experience'] > 6]
# Out:
#    Department Employee  Salary  Experience           City
# 1       Sales    Emp_2   78555           8         Austin
# 5          IT    Emp_6   97121          11        Chicago
# 7     Finance    Emp_8  119475          10       New York
# 8     Finance    Emp_9   49457           7        Chicago
# 9       Sales   Emp_10   96557          10        Chicago
# 10  Marketing   Emp_11  107189           9       New York
# 11    Finance   Emp_12  108953          12         Austin
# 12      Sales   Emp_13   82995           7       New York
# 13         IT   Emp_14   70757           9         Austin
# 14  Marketing   Emp_15   39692           8        Chicago
# 15         IT   Emp_16   75758          12        Chicago
# 18         HR   Emp_19   95697           7         Austin
# 19  Marketing   Emp_20   67065           7  San Francisco
# 20         IT   Emp_21   62606          14  San Francisco
# 21      Sales   Emp_22   41534           8       New York
# ...

# %%
df[df['Experience'] > 6].count()
# Out:
# Department    30
# Employee      30
# Salary        30
# Experience    30
# City          30
# dtype: int64

# %%
df.head()
# Out:
#   Department Employee  Salary  Experience           City
# 0  Marketing    Emp_1   53483           1       New York
# 1      Sales    Emp_2   78555           8         Austin
# 2    Finance    Emp_3   47159           3         Austin
# 3      Sales    Emp_4  110077           3  San Francisco
# 4      Sales    Emp_5   65920           1       New York

# %%
df.groupby('Department')

# %%
df_grouped = df.groupby('Department')

# %%
df_grouped.count()
# Out:
#             Employee  Salary  Experience  City
# Department
# Finance           10      10          10    10
# HR                 7       7           7     7
# IT                10      10          10    10
# Marketing         13      13          13    13
# Sales             10      10          10    10

# %%
df_grouped

# %%
df_grouped.describe()
# Out:
#            Salary                                                          \
#             count          mean           std      min       25%      50%
# Department
# Finance      10.0  90552.700000  27228.231832  47159.0  73222.00  96591.5
# HR            7.0  76182.571429  31647.523983  31016.0  55114.50  78984.0
# IT           10.0  63381.600000  24272.881041  32568.0  39755.25  66681.5
# Marketing    13.0  79555.000000  28431.207129  39268.0  54300.00  70774.0
# Sales        10.0  81038.900000  26623.181534  38571.0  68987.50  80775.0
#
#                                 Experience                                \
#                   75%       max      count      mean       std  min  25%
# Department
# Finance     111836.75  119812.0       10.0  6.500000  3.566822  1.0  3.5
# HR           96630.00  119789.0        7.0  8.714286  4.572173  3.0  5.0
# IT           79850.00   97121.0       10.0  9.000000  4.163332  1.0  7.5
# ...

# %%
df_grouped['Salary']

# %%
df_grouped['Salary'].mean()
# Out:
# Department
# Finance      90552.700000
# HR           76182.571429
# IT           63381.600000
# Marketing    79555.000000
# Sales        81038.900000
# Name: Salary, dtype: float64

# %%
df_grouped_cities = df.groupby('City')

# %%
df_grouped_cities.count()
# Out:
#                Department  Employee  Salary  Experience
# City
# Austin                 13        13      13          13
# Chicago                11        11      11          11
# New York               15        15      15          15
# San Francisco          11        11      11          11

# %%
df_grouped_cities.describe()
# Out:
#               Salary                                                         \
#                count          mean           std      min      25%      50%
# City
# Austin          13.0  81216.000000  27010.770975  38571.0  54300.0  78555.0
# Chicago         11.0  76869.363636  23718.116389  39692.0  59278.0  81214.0
# New York        15.0  70484.133333  33208.693076  31016.0  38396.0  68044.0
# San Francisco   11.0  87144.727273  24874.543739  39268.0  68731.0  91228.0
#
#                                   Experience                                \
#                     75%       max      count      mean       std  min  25%
# City
# Austin         104065.0  119812.0       13.0  6.000000  3.582364  1.0  3.0
# Chicago         96839.0  102409.0       11.0  7.909091  3.477198  2.0  6.0
# New York        95092.0  119789.0       15.0  6.800000  4.296178  1.0  3.0
# San Francisco  105644.0  116807.0       11.0  7.818182  4.556713  1.0  5.0
#
#
#                50%   75%   max
# City
# ...

# %%
df_grouped_cities['Salary'].mean()
# Out:
# City
# Austin           81216.000000
# Chicago          76869.363636
# New York         70484.133333
# San Francisco    87144.727273
# Name: Salary, dtype: float64

# %%
df_grouped_cities['Experience'].mean()
# Out:
# City
# Austin           6.000000
# Chicago          7.909091
# New York         6.800000
# San Francisco    7.818182
# Name: Experience, dtype: float64
